# %%
import pandas as pd
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler
import os
# %cd /cluster2/home/futing/Project/HiCQTL/merged/CRC53/covariate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.decomposition import PCA
#       3 from sklearn.preprocessing import StandardScaler
#       4 import os
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# #### 处理 genotype 和 depth

# %%
coolinfo=pd.read_csv('/cluster2/home/futing/Project/panCancer/QC/nContacts/hicInfo_Aug04.txt',sep='\t')
filelist=pd.read_csv('../genotype/CRC53/CRC53.psam',sep='\t')
genoPC=pd.read_csv('CRCgeno5.eigenvec',sep=' ',header=None)
genoPC=genoPC.drop(columns=[0]) # 去掉第一列
genoPC.columns=['cell']+["PC" + str(i) for i in range(1,6)] # 设置列名

# %%
coolinfo['element']=coolinfo['element'].str.replace(',','')

# %%
covariate=pd.merge(coolinfo[['cell','element']],genoPC,on='cell',how='right')
covariate=covariate.set_index('cell')
covariate['tumor'] = [0 if x.endswith('_Normal') else 1 for x in covariate.index]
# covariate = covariate.T
# covariate.head(8)

# %% [markdown]
# ### phenotype PC

# %%
expr=pd.read_csv('/cluster2/home/futing/Project/HiCQTL/merged/CRC53/phenotype/CRC53_Aug04fil.bed',sep='\t')

expr.head()
# Out:
# /tmp/ipykernel_96656/2441365460.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   expr=pd.read_csv('/cluster2/home/futing/Project/HiCQTL/merged/CRC53/phenotype/CRC53_Aug04fil.bed',sep='\t')
#   chr   start     end  gene    09-376   11-1026   11-1074  11-1074_Normal  \
# 0   1  890000  895000   178  0.721850  0.901089  0.839639        0.330144
# 1   1  895000  900000   179  0.540577  0.595470  0.650683        0.389669
# 2   1  900000  905000   180  0.418510  0.642061  0.561610        0.451869
# 3   1  905000  910000   181  0.497176  0.356007  0.261403        0.214934
# 4   1  910000  915000   182  0.814550  0.834990  0.563191        0.274900
#
#       11-51  11-51_Normal  ...     14-91   15-1382   15-1420    15-418  \
# 0  0.312873      0.727936  ...  0.256476  1.384033  0.912626  0.379787
# 1 -0.254923      0.668293  ...  0.210331  0.905053  0.605062  0.557428
# 2 -0.214719      0.916896  ... -0.009144  0.866584  0.759631  0.540593
# 3  0.068536      0.341432  ... -0.015539  0.695639  0.733940  0.361112
# 4  0.074303      0.271685  ...  0.370163  0.901901  0.828751  0.348402
#
#      15-446    16-178  16-178_Normal     SW480       DKO    HCT116
# 0  0.659389  0.668441       1.320379  0.989169  0.998001  1.662335
# 1  0.368272  0.516904       0.907322  0.562468  0.891386  1.520709
# 2  0.420482  0.781214       0.543994  0.251199  0.787745  1.590608
# 3  0.640313  0.426678      -0.188751  0.359788  0.682265  1.415113
# 4  0.670816  0.333805      -0.137275  0.674101  0.779230  1.365818
#
# [5 rows x 57 columns]

# %%
expr.shape
# Out:
# (523925, 57)

# %%
df=expr.drop(columns=['chr','start','end','gene']).T
# 1. 标准化数据（PCA 对量纲很敏感）
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# 2. 建立 PCA 模型，保留前 2 个主成分
pca = PCA(n_components=20)
X_pca = pca.fit_transform(X_scaled)

# %%
expr_pc = pd.DataFrame(X_pca)

# %%
expr_pc.columns = ["exprPC" + str(i) for i in range(1,21)]
expr_pc.index = df.index
expr_pc = expr_pc.T

# %%
covariate1=pd.merge(covariate,expr_pc,    left_index=True, # 使用左边 DataFrame 的 index 作为合并键
    right_index=True,# 使用右边 DataFrame 的 index 作为合并键
    how='inner')

# %%
expr_pc.head()
# Out:
#                    exprPC1      exprPC2     exprPC3    exprPC4    exprPC5  \
# 09-376          -32.469536     5.025508   62.431690  27.343436  35.683972
# 11-1026          20.948009     2.306893  -11.777108 -37.028617 -45.781367
# 11-1074          27.723590   -11.725865  -33.764099 -41.074673 -25.725099
# 11-1074_Normal -227.098656   -33.078190   12.176605  91.931157  35.082728
# 11-51            13.079399  1013.463839 -234.405582  82.653652  46.826935
#
#                   exprPC6     exprPC7    exprPC8     exprPC9    exprPC10  \
# 09-376         -63.211381  147.185168 -41.500747 -141.568693 -105.102317
# 11-1026        -51.502940   41.526234  -3.401390   16.287898   50.445554
# 11-1074        -39.631904   -8.273862  41.376966   47.622360   14.840857
# 11-1074_Normal  11.079436    7.462961 -67.169847   -1.722867  -66.196851
# 11-51           52.337428  -23.445888  -2.943633    7.231629    3.794739
#
#                  exprPC11   exprPC12    exprPC13    exprPC14    exprPC15  \
# 09-376          16.871908 -78.260813   45.069263  205.809101 -157.676176
# 11-1026         20.383937   7.512367 -106.905563  -51.199361    7.636216
# 11-1074         61.925721 -17.671499  -31.589429   48.123699  -11.472450
# 11-1074_Normal -67.966761 -83.721279    9.997717  -37.559545   15.214718
# 11-51           -0.290335  -8.482031   12.462659  -10.146362    2.410811
#
#                   exprPC16    exprPC17    exprPC18    exprPC19    exprPC20
# 09-376           16.533968  218.643038  411.150123 -202.629085 -160.735699
# 11-1026        -137.892767   30.033984   93.080076 -185.002620  284.792637
# 11-1074        -117.034964   21.035607   34.771950  -23.949846  -15.251843
# 11-1074_Normal   -0.903634   -9.979047    3.926240   48.219625   34.421041
# 11-51            13.709846   -1.189816   -5.538519   11.010104  -11.655095

# %%
covariate1=covariate1.T

# %%
covariate1.to_csv('covariate27.txt',sep='\t')
